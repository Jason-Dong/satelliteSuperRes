# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os
import torch
import torchvision.transforms as transforms

# %%
img = np.array(Image.open("data/train/NIR/imgset0594/HR.png"))

# %%
print(img.shape)
plt.imshow(img, cmap='gray')
# Out:
# (384, 384)

# %%
from data import *

# %%
oof = TrainNIRDataset(upsample=True)
batch=oof[0]
# Out:
# ../torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-1f6cf90af9fa> in <module>()
#       1 oof = TrainREDDataset(upsample=True)
# ----> 2 batch=oof[0]
#
# /Users/jason/Desktop/Satellite/satelliteSupreRes/data.py in __getitem__(self, idx)
#     120         selected_LR = np.random.choice(num_LR, 9, replace=False)
#     121         LR_imgs = torch.cat([self.transform(Image.open(imgs_path + '/LR{}.png'.format(('00' + str(val)) if val < 10 else ('0' + str(val)))))
# --> 122                             for val in selected_LR]).resize_((1, 9, self.size, self.size))
#     123
#     124
#
# AttributeError: 'TrainREDDataset' object has no attribute 'size'

# %%
print(batch['LR'].shape)
print(batch['HR'].shape)

# %%
plt.imshow(batch['LR'][0][0], cmap='gray')

# %%
print(batch['LR'][0][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bc3730839433> in <module>()
# ----> 1 print(batch['LR'][0][0])
#
# NameError: name 'batch' is not defined

# %%
plt.imshow(batch['HR'], cmap='gray')

# %%
oof2 = torch.utils.data.DataLoader(oof, batch_size=32, shuffle=False, num_workers=0)
oof3 = iter(oof2)

# %%
# print(next(iter(oof2)))
print(next(oof3)['LR'].shape)
