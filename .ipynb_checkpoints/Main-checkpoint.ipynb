# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import os

# %%
img = np.array(Image.open("data/train/NIR/imgset0594/LR011.png"))

# %%
print(img.shape)
plt.imshow(img, cmap='gray')
# Out:
# (128, 128)

# %%
class TrainNIRDataset(Dataset):
    """Some Satellite Shit."""

    def __init__(self, transform=None):
        """
        Args:
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.transform = transform
        
    def __len__(self):
        return 566

    def __getitem__(self, idx):
        594 + idx
        img_set_num = 594 + idx
        img_set_filename = '0' + str(img_set_num) if img_set_num < 1000 else str(img_set_num)
        imgs_path = os.join('data/train/NIR', img_set_filename)
        
        num_LR = len([name for name in os.listdir(img_path)]) / 2 - 1
        LR_imgs = np.concatenate([
            np.array(Image.open('LR' + ('00' + str(val)) if val < 10 else ('0' + str(val)) + '.png')) for val in range(num_LR)])
        HR_img = np.array(Image.open('HR.png'))
        sample = {'LR': LR_imgs, 'HR': HR_img}
        return sample
    
class TestNIRDataset(Dataset):
    """Some Satellite Shit."""

    def __init__(self, transform=None):
        """
        Args:
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.transform = transform
        
    def __len__(self):
        return 144

    def __getitem__(self, idx):
        
        
        sample = {'LR': image}
        return
    
class TrainREDDataset(Dataset):
    """Some Satellite Shit."""

    def __init__(self, transform=None):
        """
        Args:
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.transform = transform
        
    def __len__(self):
        return 594

    def __getitem__(self, idx):
        
        
        
        sample = {'LR': image, 'HR': landmarks}
        return
    
class TestREDDataset(Dataset):
    """Some Satellite Shit."""

    def __init__(self, transform=None):
        """
        Args:
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.transform = transform
        
    def __len__(self):
        return 146

    def __getitem__(self, idx):
        
        images_path = os.join('data', '')
        
        sample = {'LR': image}
        return
